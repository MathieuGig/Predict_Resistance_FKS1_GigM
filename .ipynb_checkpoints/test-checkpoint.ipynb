# %% [markdown]
# # Title: Predict_orthologs
# ### Author: Mathieu Giguere
#
# Brief: Uses machine learning to predict the resistance of FKS1-HS1 Orthologs amino acid sequences to an antifungal drug by training a model on single mutants amino acid sequences. The model uses Expasy Protscale's amino acid properties as features.
#
# Preconditions: Needs Romain Durand's 'nt_refined_classification.csv' from his 'DMS-main' repository and 'aminoAcidProperties.txt'.

# %%
# importing modules and packages
import pandas as pd
import numpy as np
np.bool = np.bool_
np.int = np.int_
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, roc_auc_score, matthews_corrcoef, roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, ShuffleSplit
import glob
import os

# %%
# For SHAP

import shap # v0.39.0
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# ## Define the antifungal drug used.

# %%
# VIP. Very important parameter. The Antifungal drug.
# Choices are : 'caspofungin', 'anidulafungin', 'micafungin'
drug = 'caspofungin'

# Dictionary to convert 3-level resistance classification to 2-level
parse_res_class = {'deleterious':'sensitive',
                   'slightly deleterious':'sensitive',
                   'WT-like':'sensitive',
                   'intermediary':'resistant',
                   'resistant':'resistant'
                  }

# %% [markdown]
# ## Specify Output Path

# %%
outpath = f'{drug}'

# %% [markdown]
# ## Make a usable dataframe from the data.

# %%
df = pd.read_csv('nt_refined_classification.csv', index_col=0)

#master = df[['compound', 'seq_type', 'Nham_aa', 'aa_seq', 's', 'aa_class']]
#master['resistance'] = np.where(master['aa_class'] == 'WT-like', 'sensitive', 'resistant')
#master = master.drop(columns='aa_class')
#drug_master = master[master['compound'] == drug]

drug_master = df[df.compound == drug][['compound', 'seq_type', 'Nham_aa', 'aa_seq', 's', 'refined_class']]
drug_master['resistance'] = drug_master.refined_class.replace(parse_res_class)
drug_master = drug_master.drop(columns='refined_class').reset_index(drop=True)
drug_master
# Out:
#         compound seq_type  Nham_aa     aa_seq         s resistance
# 0    caspofungin    ortho      1.0  FLILSLRDP -0.174894  sensitive
# 1    caspofungin    ortho      1.0  FLTLSLRDP  0.128204  sensitive
# 2    caspofungin    ortho      2.0  FLALSFRDP -0.150999  sensitive
# 3    caspofungin    ortho      2.0  FLALSIRDP -0.009226  sensitive
# 4    caspofungin    ortho      2.0  FLSLSFRDP  1.352185  resistant
# ..           ...      ...      ...        ...       ...        ...
# 311  caspofungin   single      1.0  TLVLSLRDP  1.331442  resistant
# 312  caspofungin   single      1.0  TLVLSLRDP  1.924182  resistant
# 313  caspofungin   single      1.0  VLVLSLRDP  1.884107  resistant
# 314  caspofungin   single      1.0  WLVLSLRDP  1.399567  resistant
# 315  caspofungin   single      1.0  YLVLSLRDP  1.916435  resistant
#
# [316 rows x 6 columns]

# %% [markdown]
# ## Import amino acid properties

# %%
# Amino acid properties
#AAproperties = pd.read_table('aminoAcidProperties.txt')
AAproperties = pd.read_csv('customAAprop.csv')
AAproperties.rename(columns={'Aminoacid.1.letter': 'aa1'}, inplace=True)
AAproperties
# Out:
#    aa1  polarity  Molar Mass  charge  aromatic
# 0   A          0          89       0         0
# 1    C         1         121       0         0
# 2    D         1         132      -1         0
# 3    E         1         146      -1         0
# 4    F         0         165       0         1
# 5    G         0          75       0         0
# 6    H         1         155       1         1
# 7    I         0         131       0         0
# 8    K         1         147       1         0
# 9    L         0         131       0         0
# 10   M         0         149       0         0
# 11   N         1         132       0         0
# 12   P         0         115       0         0
# 13   Q         1         146       0         0
# 14   R         1         175       1         0
# 15   S         1         105       0         0
# 16   T         1         119       0         0
# 17   V         0         117       0         0
# 18   W         0         204       0         1
# 19   Y         1         181       0         1

# %% [markdown]
# ## Create training dataframe on single mutants

# %%
#Single_master = drug_master.loc[(drug_master['seq_type'] == 'single')]

Single_master = drug_master.loc[drug_master.Nham_aa <=1]

# Explode aa_seq into many columns
Single_master[['aa1', 'aa2', 'aa3', 'aa4', 'aa5', 'aa6', 'aa7', 'aa8', 'aa9']] = Single_master['aa_seq'].apply(lambda x: pd.Series(list(x)))


#Single_master.to_csv(f'{outpath}/{drug}_input.csv', index=False)
Single_master
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         compound seq_type  Nham_aa     aa_seq         s resistance aa1 aa2  \
# 0    caspofungin    ortho      1.0  FLILSLRDP -0.174894  sensitive   F   L
# 1    caspofungin    ortho      1.0  FLTLSLRDP  0.128204  sensitive   F   L
# 48   caspofungin   single      0.0  FLVLSLRDP -0.300610  sensitive   F   L
# 49   caspofungin   single      0.0  FLVLSLRDP  0.032684  sensitive   F   L
# 50   caspofungin   single      0.0  FLVLSLRDP  1.043896  resistant   F   L
# ..           ...      ...      ...        ...       ...        ...  ..  ..
# 311  caspofungin   single      1.0  TLVLSLRDP  1.331442  resistant   T   L
# 312  caspofungin   single      1.0  TLVLSLRDP  1.924182  resistant   T   L
# 313  caspofungin   single      1.0  VLVLSLRDP  1.884107  resistant   V   L
# 314  caspofungin   single      1.0  WLVLSLRDP  1.399567  resistant   W   L
# 315  caspofungin   single      1.0  YLVLSLRDP  1.916435  resistant   Y   L
#
#     aa3 aa4 aa5 aa6 aa7 aa8 aa9
# 0     I   L   S   L   R   D   P
# 1     T   L   S   L   R   D   P
# 48    V   L   S   L   R   D   P
# 49    V   L   S   L   R   D   P
# 50    V   L   S   L   R   D   P
# ..   ..  ..  ..  ..  ..  ..  ..
# 311   V   L   S   L   R   D   P
# 312   V   L   S   L   R   D   P
# 313   V   L   S   L   R   D   P
# 314   V   L   S   L   R   D   P
# 315   V   L   S   L   R   D   P
#
# [270 rows x 15 columns]

# %%
# Merge dataframe with AAproperties
Single_merged = pd.merge(left=Single_master, right=AAproperties, how='inner', indicator='location1', suffixes=(None, '_aa1'), on='aa1')

AAproperties.rename(columns={'aa1': 'aa2'}, inplace=True)
Single_merged = pd.merge(left=Single_merged, right=AAproperties, how='inner', indicator='location2', suffixes=(None, '_aa2'),
                  on='aa2')

AAproperties.rename(columns={'aa2': 'aa3'}, inplace=True)
Single_merged = pd.merge(left=Single_merged, right=AAproperties, how='inner', indicator='location3', suffixes=(None, '_aa3'),
                  on='aa3')

AAproperties.rename(columns={'aa3': 'aa4'}, inplace=True)
Single_merged = pd.merge(left=Single_merged, right=AAproperties, how='inner', indicator='location4', suffixes=(None, '_aa4'),
                  on='aa4')

AAproperties.rename(columns={'aa4': 'aa5'}, inplace=True)
Single_merged = pd.merge(left=Single_merged, right=AAproperties, how='inner', indicator='location5', suffixes=(None, '_aa5'),
                  on='aa5')

AAproperties.rename(columns={'aa5': 'aa6'}, inplace=True)
Single_merged = pd.merge(left=Single_merged, right=AAproperties, how='inner', indicator='location6', suffixes=(None, '_aa6'),
                  on='aa6')

AAproperties.rename(columns={'aa6': 'aa7'}, inplace=True)
Single_merged = pd.merge(left=Single_merged, right=AAproperties, how='inner', indicator='location7', suffixes=(None, '_aa7'),
                  on='aa7')

AAproperties.rename(columns={'aa7': 'aa8'}, inplace=True)
Single_merged = pd.merge(left=Single_merged, right=AAproperties, how='inner', indicator='location8', suffixes=(None, '_aa8'),
                  on='aa8')

AAproperties.rename(columns={'aa8': 'aa9'}, inplace=True)
Single_merged = pd.merge(left=Single_merged, right=AAproperties, how='inner', indicator='location9', suffixes=(None, '_aa9'),
                  on='aa9')

Single_merged
# Out:
#         compound seq_type  Nham_aa     aa_seq         s resistance aa1 aa2  \
# 0    caspofungin    ortho      1.0  FLILSLRDP -0.174894  sensitive   F   L
# 1    caspofungin   single      1.0  FLILSLRDP  0.093658  sensitive   F   L
# 2    caspofungin    ortho      1.0  FLTLSLRDP  0.128204  sensitive   F   L
# 3    caspofungin   single      1.0  FLTLSLRDP  0.440090  sensitive   F   L
# 4    caspofungin   single      1.0  FLTLSLRDP -0.204930  sensitive   F   L
# ..           ...      ...      ...        ...       ...        ...  ..  ..
# 238  caspofungin   single      1.0  FLVLSLRDT  1.895916  resistant   F   L
# 239  caspofungin   single      1.0  FLVLSLRDV  1.841924  resistant   F   L
# 240  caspofungin   single      1.0  FLVLSLRDV  1.791736  resistant   F   L
# 241  caspofungin   single      1.0  FLVLSLRDW  0.081155  sensitive   F   L
# 242  caspofungin   single      1.0  FLVLSLRDY  1.730189  resistant   F   L
#
#     aa3 aa4  ... polarity_aa8 Molar Mass_aa8 charge_aa8 aromatic_aa8  \
# 0     I   L  ...            1            132         -1            0
# 1     I   L  ...            1            132         -1            0
# 2     T   L  ...            1            132         -1            0
# 3     T   L  ...            1            132         -1            0
# 4     T   L  ...            1            132         -1            0
# ..   ..  ..  ...          ...            ...        ...          ...
# 238   V   L  ...            1            132         -1            0
# 239   V   L  ...            1            132         -1            0
# 240   V   L  ...            1            132         -1            0
# 241   V   L  ...            1            132         -1            0
# 242   V   L  ...            1            132         -1            0
#
#     location8  polarity_aa9  Molar Mass_aa9  charge_aa9  aromatic_aa9  \
# 0        both             0             115           0             0
# 1        both             0             115           0             0
# 2        both             0             115           0             0
# 3        both             0             115           0             0
# 4        both             0             115           0             0
# ..        ...           ...             ...         ...           ...
# 238      both             1             119           0             0
# 239      both             0             117           0             0
# 240      both             0             117           0             0
# 241      both             0             204           0             1
# 242      both             1             181           0             1
#
#     location9
# 0        both
# 1        both
# 2        both
# 3        both
# 4        both
# ..        ...
# 238      both
# 239      both
# 240      both
# 241      both
# 242      both
#
# [243 rows x 60 columns]

# %%
# Get training data for machine learning.
X_train = Single_merged.drop(columns=['seq_type', 'aa_seq', 'compound', 's', 'Nham_aa', 'resistance',
                                      'location1', 'location2', 'location3', 'location4', 'location5', 'location6', 'location7', 'location8', 'location9',
                                      'aa1', 'aa2', 'aa3', 'aa4', 'aa5', 'aa6', 'aa7', 'aa8', 'aa9'])

X_train
# Out:
#      polarity  Molar Mass  charge  aromatic  polarity_aa2  Molar Mass_aa2  \
# 0           0         165       0         1             0             131
# 1           0         165       0         1             0             131
# 2           0         165       0         1             0             131
# 3           0         165       0         1             0             131
# 4           0         165       0         1             0             131
# ..        ...         ...     ...       ...           ...             ...
# 238         0         165       0         1             0             131
# 239         0         165       0         1             0             131
# 240         0         165       0         1             0             131
# 241         0         165       0         1             0             131
# 242         0         165       0         1             0             131
#
#      charge_aa2  aromatic_aa2  polarity_aa3  Molar Mass_aa3  ...  charge_aa7  \
# 0             0             0             0             131  ...           1
# 1             0             0             0             131  ...           1
# 2             0             0             1             119  ...           1
# 3             0             0             1             119  ...           1
# 4             0             0             1             119  ...           1
# ..          ...           ...           ...             ...  ...         ...
# 238           0             0             0             117  ...           1
# 239           0             0             0             117  ...           1
# 240           0             0             0             117  ...           1
# 241           0             0             0             117  ...           1
# 242           0             0             0             117  ...           1
#
#      aromatic_aa7  polarity_aa8  Molar Mass_aa8  charge_aa8  aromatic_aa8  \
# 0               0             1             132          -1             0
# 1               0             1             132          -1             0
# 2               0             1             132          -1             0
# 3               0             1             132          -1             0
# 4               0             1             132          -1             0
# ..            ...           ...             ...         ...           ...
# 238             0             1             132          -1             0
# 239             0             1             132          -1             0
# 240             0             1             132          -1             0
# 241             0             1             132          -1             0
# 242             0             1             132          -1             0
#
#      polarity_aa9  Molar Mass_aa9  charge_aa9  aromatic_aa9
# 0               0             115           0             0
# 1               0             115           0             0
# 2               0             115           0             0
# 3               0             115           0             0
# 4               0             115           0             0
# ..            ...             ...         ...           ...
# 238             1             119           0             0
# 239             0             117           0             0
# 240             0             117           0             0
# 241             0             204           0             1
# 242             1             181           0             1
#
# [243 rows x 36 columns]

# %%
y_train = Single_merged['resistance']

y_train
# Out:
# 0      sensitive
# 1      sensitive
# 2      sensitive
# 3      sensitive
# 4      sensitive
#          ...
# 238    resistant
# 239    resistant
# 240    resistant
# 241    sensitive
# 242    resistant
# Name: resistance, Length: 243, dtype: object

# %%
#Density plot
sns.histplot(data=Single_master, x='s', element='step')
plt.title('Resistance Score Histogram', fontsize=24)
plt.xlabel('Resistance score', fontsize=20)
plt.ylabel('Count', fontsize=20)
plt.gca().tick_params(labelsize=18)
plt.tight_layout()
#plt.savefig(f'{drug}_SinglesDensity.svg')
plt.show()

# %% [markdown]
# ## Create Orthologs Prediction (test) dataframe

# %%
#Ortho_master = drug_master.loc[(drug_master['seq_type'] == 'ortho')]

#Ortho_master = drug_master.loc[~drug_master.aa_seq.isin(Single_master.aa_seq.unique())]
Ortho_master = drug_master.loc[drug_master.Nham_aa > 1]

# Explode aa_seq into many columns
Ortho_master[['aa1', 'aa2', 'aa3', 'aa4', 'aa5', 'aa6', 'aa7', 'aa8', 'aa9']] = Ortho_master['aa_seq'].apply(lambda x: pd.Series(list(x)))

Ortho_master
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        compound seq_type  Nham_aa     aa_seq         s resistance aa1 aa2 aa3  \
# 2   caspofungin    ortho      2.0  FLALSFRDP -0.150999  sensitive   F   L   A
# 3   caspofungin    ortho      2.0  FLALSIRDP -0.009226  sensitive   F   L   A
# 4   caspofungin    ortho      2.0  FLSLSFRDP  1.352185  resistant   F   L   S
# 5   caspofungin    ortho      2.0  FLTLSFRDP  0.194558  sensitive   F   L   T
# 6   caspofungin    ortho      2.0  FLTLSIRDP  0.112074  sensitive   F   L   T
# 7   caspofungin    ortho      2.0  FLTLSLKDP -0.069431  sensitive   F   L   T
# 8   caspofungin    ortho      2.0  FLTLSLRDA  1.771898  resistant   F   L   T
# 9   caspofungin    ortho      2.0  FLTLSLVDP -0.391748  sensitive   F   L   T
# 10  caspofungin    ortho      2.0  FLTLSVRDP  0.029610  sensitive   F   L   T
# 11  caspofungin    ortho      2.0  FMALSLRDP  0.173952  sensitive   F   M   A
# 12  caspofungin    ortho      2.0  YLILSLRDP  1.894492  resistant   Y   L   I
# 13  caspofungin    ortho      2.0  YLTLSLRDP  2.012839  resistant   Y   L   T
# 14  caspofungin    ortho      3.0  ALTLSFRDP  1.990216  resistant   A   L   T
# 15  caspofungin    ortho      3.0  FLALSFKDP -0.099607  sensitive   F   L   A
# 16  caspofungin    ortho      3.0  FLALSFRDA  1.933761  resistant   F   L   A
# 17  caspofungin    ortho      3.0  FLIKSLIDP -0.073667  sensitive   F   L   I
# 18  caspofungin    ortho      3.0  FLTHSFRDP  1.953348  resistant   F   L   T
# 19  caspofungin    ortho      3.0  FLTLSAKDP -0.257784  sensitive   F   L   T
# 20  caspofungin    ortho      3.0  FLTLSFKDP  0.144595  sensitive   F   L   T
# 21  caspofungin    ortho      3.0  FLTLSFRDT  0.203105  sensitive   F   L   T
# 22  caspofungin    ortho      3.0  FLTLSIKDP -0.133317  sensitive   F   L   T
# 23  caspofungin    ortho      3.0  YLALSFRDP  1.929665  resistant   Y   L   A
# 24  caspofungin    ortho      3.0  YLILSFRDP  1.959712  resistant   Y   L   I
# 25  caspofungin    ortho      3.0  YLILSIRDP  1.984993  resistant   Y   L   I
# 26  caspofungin    ortho      3.0  YLTLSFRDP  1.930501  resistant   Y   L   T
# 27  caspofungin    ortho      3.0  YLTLSIRDP  1.975241  resistant   Y   L   T
# 28  caspofungin    ortho      4.0  FLALNLSDS  1.955422  resistant   F   L   A
# 29  caspofungin    ortho      4.0  FLTLNLADS  2.031950  resistant   F   L   T
# 30  caspofungin    ortho      4.0  FLTLNLSDS  1.950944  resistant   F   L   T
# 31  caspofungin    ortho      4.0  FLTLSFENP  0.847983  resistant   F   L   T
# 32  caspofungin    ortho      4.0  SLTLSFRDV  1.943469  resistant   S   L   T
# 33  caspofungin    ortho      4.0  YLALSFKDP  1.927187  resistant   Y   L   A
# 34  caspofungin    ortho      4.0  YLTLSFKDP  1.897366  resistant   Y   L   T
# 35  caspofungin    ortho      4.0  YLTLSFRDA  1.979639  resistant   Y   L   T
# 36  caspofungin    ortho      4.0  YLTLSFRDV  1.797126  resistant   Y   L   T
# 37  caspofungin    ortho      4.0  YLTLSFSDP  1.944635  resistant   Y   L   T
# 38  caspofungin    ortho      4.0  YLTLSIKDP  1.916642  resistant   Y   L   T
# 39  caspofungin    ortho      4.0  YLTRSFRDP  2.006457  resistant   Y   L   T
# 40  caspofungin    ortho      5.0  ALALNIKDP  2.029951  resistant   A   L   A
# 41  caspofungin    ortho      5.0  FLTSSFSSP  1.937878  resistant   F   L   T
# 42  caspofungin    ortho      5.0  YLTLAFRDS  1.938061  resistant   Y   L   T
# 43  caspofungin    ortho      6.0  YLTRAFRDS  1.958904  resistant   Y   L   T
# 44  caspofungin    ortho      7.0  AICSDLRED  1.732953  resistant   A   I   C
# 45  caspofungin    ortho      7.0  LQIRPLIAP  2.047163  resistant   L   Q   I
# 46  caspofungin    ortho      7.0  LQVKPMIKP  2.020696  resistant   L   Q   V
# 47  caspofungin    ortho      7.0  VLTLLVTQH  1.604155  resistant   V   L   T
#
#    aa4 aa5 aa6 aa7 aa8 aa9
# 2    L   S   F   R   D   P
# 3    L   S   I   R   D   P
# 4    L   S   F   R   D   P
# 5    L   S   F   R   D   P
# 6    L   S   I   R   D   P
# 7    L   S   L   K   D   P
# 8    L   S   L   R   D   A
# 9    L   S   L   V   D   P
# 10   L   S   V   R   D   P
# 11   L   S   L   R   D   P
# 12   L   S   L   R   D   P
# 13   L   S   L   R   D   P
# 14   L   S   F   R   D   P
# 15   L   S   F   K   D   P
# 16   L   S   F   R   D   A
# 17   K   S   L   I   D   P
# 18   H   S   F   R   D   P
# 19   L   S   A   K   D   P
# 20   L   S   F   K   D   P
# 21   L   S   F   R   D   T
# 22   L   S   I   K   D   P
# 23   L   S   F   R   D   P
# 24   L   S   F   R   D   P
# 25   L   S   I   R   D   P
# 26   L   S   F   R   D   P
# 27   L   S   I   R   D   P
# 28   L   N   L   S   D   S
# 29   L   N   L   A   D   S
# 30   L   N   L   S   D   S
# 31   L   S   F   E   N   P
# 32   L   S   F   R   D   V
# 33   L   S   F   K   D   P
# 34   L   S   F   K   D   P
# 35   L   S   F   R   D   A
# 36   L   S   F   R   D   V
# 37   L   S   F   S   D   P
# 38   L   S   I   K   D   P
# 39   R   S   F   R   D   P
# 40   L   N   I   K   D   P
# 41   S   S   F   S   S   P
# 42   L   A   F   R   D   S
# 43   R   A   F   R   D   S
# 44   S   D   L   R   E   D
# 45   R   P   L   I   A   P
# 46   K   P   M   I   K   P
# 47   L   L   V   T   Q   H

# %%
# Merge dataframe with AAproperties
AAproperties.rename(columns={'aa9': 'aa1'}, inplace=True)
Ortho_merged = pd.merge(left=Ortho_master, right=AAproperties, how='inner', indicator='location1', suffixes=(None, '_aa1'),
                  on='aa1')

AAproperties.rename(columns={'aa1': 'aa2'}, inplace=True)
Ortho_merged = pd.merge(left=Ortho_merged, right=AAproperties, how='inner', indicator='location2', suffixes=(None, '_aa2'),
                  on='aa2')

AAproperties.rename(columns={'aa2': 'aa3'}, inplace=True)
Ortho_merged = pd.merge(left=Ortho_merged, right=AAproperties, how='inner', indicator='location3', suffixes=(None, '_aa3'),
                  on='aa3')

AAproperties.rename(columns={'aa3': 'aa4'}, inplace=True)
Ortho_merged = pd.merge(left=Ortho_merged, right=AAproperties, how='inner', indicator='location4', suffixes=(None, '_aa4'),
                  on='aa4')

AAproperties.rename(columns={'aa4': 'aa5'}, inplace=True)
Ortho_merged = pd.merge(left=Ortho_merged, right=AAproperties, how='inner', indicator='location5', suffixes=(None, '_aa5'),
                  on='aa5')

AAproperties.rename(columns={'aa5': 'aa6'}, inplace=True)
Ortho_merged = pd.merge(left=Ortho_merged, right=AAproperties, how='inner', indicator='location6', suffixes=(None, '_aa6'),
                  on='aa6')

AAproperties.rename(columns={'aa6': 'aa7'}, inplace=True)
Ortho_merged = pd.merge(left=Ortho_merged, right=AAproperties, how='inner', indicator='location7', suffixes=(None, '_aa7'),
                  on='aa7')

AAproperties.rename(columns={'aa7': 'aa8'}, inplace=True)
Ortho_merged = pd.merge(left=Ortho_merged, right=AAproperties, how='inner', indicator='location8', suffixes=(None, '_aa8'),
                  on='aa8')

AAproperties.rename(columns={'aa8': 'aa9'}, inplace=True)
Ortho_merged = pd.merge(left=Ortho_merged, right=AAproperties, how='inner', indicator='location9', suffixes=(None, '_aa9'),
                  on='aa9')

Ortho_merged
# Out:
#        compound seq_type  Nham_aa     aa_seq         s resistance aa1 aa2 aa3  \
# 0   caspofungin    ortho      2.0  FLSLSFRDP  1.352185  resistant   F   L   S
# 1   caspofungin    ortho      2.0  FLTLSFRDP  0.194558  sensitive   F   L   T
# 2   caspofungin    ortho      3.0  YLTLSFRDP  1.930501  resistant   Y   L   T
# 3   caspofungin    ortho      3.0  YLILSFRDP  1.959712  resistant   Y   L   I
# 4   caspofungin    ortho      3.0  FLTHSFRDP  1.953348  resistant   F   L   T
# 5   caspofungin    ortho      4.0  YLTRSFRDP  2.006457  resistant   Y   L   T
# 6   caspofungin    ortho      2.0  FLTLSIRDP  0.112074  sensitive   F   L   T
# 7   caspofungin    ortho      3.0  YLTLSIRDP  1.975241  resistant   Y   L   T
# 8   caspofungin    ortho      3.0  YLILSIRDP  1.984993  resistant   Y   L   I
# 9   caspofungin    ortho      2.0  YLTLSLRDP  2.012839  resistant   Y   L   T
# 10  caspofungin    ortho      2.0  YLILSLRDP  1.894492  resistant   Y   L   I
# 11  caspofungin    ortho      2.0  FLTLSVRDP  0.029610  sensitive   F   L   T
# 12  caspofungin    ortho      3.0  FLTLSFKDP  0.144595  sensitive   F   L   T
# 13  caspofungin    ortho      4.0  YLTLSFKDP  1.897366  resistant   Y   L   T
# 14  caspofungin    ortho      3.0  FLTLSIKDP -0.133317  sensitive   F   L   T
# 15  caspofungin    ortho      4.0  YLTLSIKDP  1.916642  resistant   Y   L   T
# 16  caspofungin    ortho      2.0  FLTLSLKDP -0.069431  sensitive   F   L   T
# 17  caspofungin    ortho      4.0  YLTLSFSDP  1.944635  resistant   Y   L   T
# 18  caspofungin    ortho      2.0  FLTLSLVDP -0.391748  sensitive   F   L   T
# 19  caspofungin    ortho      3.0  FLIKSLIDP -0.073667  sensitive   F   L   I
# 20  caspofungin    ortho      4.0  FLTLSFENP  0.847983  resistant   F   L   T
# 21  caspofungin    ortho      5.0  FLTSSFSSP  1.937878  resistant   F   L   T
# 22  caspofungin    ortho      7.0  LQVKPMIKP  2.020696  resistant   L   Q   V
# 23  caspofungin    ortho      3.0  FLTLSFRDT  0.203105  sensitive   F   L   T
# 24  caspofungin    ortho      4.0  YLTLSFRDV  1.797126  resistant   Y   L   T
# 25  caspofungin    ortho      4.0  SLTLSFRDV  1.943469  resistant   S   L   T
# 26  caspofungin    ortho      4.0  FLTLNLSDS  1.950944  resistant   F   L   T
# 27  caspofungin    ortho      7.0  VLTLLVTQH  1.604155  resistant   V   L   T
#
#    aa4  ... polarity_aa8 Molar Mass_aa8 charge_aa8 aromatic_aa8 location8  \
# 0    L  ...            1            132         -1            0      both
# 1    L  ...            1            132         -1            0      both
# 2    L  ...            1            132         -1            0      both
# 3    L  ...            1            132         -1            0      both
# 4    H  ...            1            132         -1            0      both
# 5    R  ...            1            132         -1            0      both
# 6    L  ...            1            132         -1            0      both
# 7    L  ...            1            132         -1            0      both
# 8    L  ...            1            132         -1            0      both
# 9    L  ...            1            132         -1            0      both
# 10   L  ...            1            132         -1            0      both
# 11   L  ...            1            132         -1            0      both
# 12   L  ...            1            132         -1            0      both
# 13   L  ...            1            132         -1            0      both
# 14   L  ...            1            132         -1            0      both
# 15   L  ...            1            132         -1            0      both
# 16   L  ...            1            132         -1            0      both
# 17   L  ...            1            132         -1            0      both
# 18   L  ...            1            132         -1            0      both
# 19   K  ...            1            132         -1            0      both
# 20   L  ...            1            132          0            0      both
# 21   S  ...            1            105          0            0      both
# 22   K  ...            1            147          1            0      both
# 23   L  ...            1            132         -1            0      both
# 24   L  ...            1            132         -1            0      both
# 25   L  ...            1            132         -1            0      both
# 26   L  ...            1            132         -1            0      both
# 27   L  ...            1            146          0            0      both
#
#     polarity_aa9  Molar Mass_aa9  charge_aa9  aromatic_aa9 location9
# 0              0             115           0             0      both
# 1              0             115           0             0      both
# 2              0             115           0             0      both
# 3              0             115           0             0      both
# 4              0             115           0             0      both
# 5              0             115           0             0      both
# 6              0             115           0             0      both
# 7              0             115           0             0      both
# 8              0             115           0             0      both
# 9              0             115           0             0      both
# 10             0             115           0             0      both
# 11             0             115           0             0      both
# 12             0             115           0             0      both
# 13             0             115           0             0      both
# 14             0             115           0             0      both
# 15             0             115           0             0      both
# 16             0             115           0             0      both
# 17             0             115           0             0      both
# 18             0             115           0             0      both
# 19             0             115           0             0      both
# 20             0             115           0             0      both
# 21             0             115           0             0      both
# 22             0             115           0             0      both
# 23             1             119           0             0      both
# 24             0             117           0             0      both
# 25             0             117           0             0      both
# 26             1             105           0             0      both
# 27             1             155           1             1      both
#
# [28 rows x 60 columns]

# %%
# Get testing data for machine learning.
X_test = Ortho_merged.drop(columns=['seq_type', 'aa_seq', 'compound', 's', 'Nham_aa', 'resistance',
                                    'location1', 'location2', 'location3', 'location4', 'location5', 'location6', 'location7', 'location8', 'location9',
                                    'aa1', 'aa2', 'aa3', 'aa4', 'aa5', 'aa6', 'aa7', 'aa8', 'aa9'])

X_test
# Out:
#     polarity  Molar Mass  charge  aromatic  polarity_aa2  Molar Mass_aa2  \
# 0          0         165       0         1             0             131
# 1          0         165       0         1             0             131
# 2          1         181       0         1             0             131
# 3          1         181       0         1             0             131
# 4          0         165       0         1             0             131
# 5          1         181       0         1             0             131
# 6          0         165       0         1             0             131
# 7          1         181       0         1             0             131
# 8          1         181       0         1             0             131
# 9          1         181       0         1             0             131
# 10         1         181       0         1             0             131
# 11         0         165       0         1             0             131
# 12         0         165       0         1             0             131
# 13         1         181       0         1             0             131
# 14         0         165       0         1             0             131
# 15         1         181       0         1             0             131
# 16         0         165       0         1             0             131
# 17         1         181       0         1             0             131
# 18         0         165       0         1             0             131
# 19         0         165       0         1             0             131
# 20         0         165       0         1             0             131
# 21         0         165       0         1             0             131
# 22         0         131       0         0             1             146
# 23         0         165       0         1             0             131
# 24         1         181       0         1             0             131
# 25         1         105       0         0             0             131
# 26         0         165       0         1             0             131
# 27         0         117       0         0             0             131
#
#     charge_aa2  aromatic_aa2  polarity_aa3  Molar Mass_aa3  ...  charge_aa7  \
# 0            0             0             1             105  ...           1
# 1            0             0             1             119  ...           1
# 2            0             0             1             119  ...           1
# 3            0             0             0             131  ...           1
# 4            0             0             1             119  ...           1
# 5            0             0             1             119  ...           1
# 6            0             0             1             119  ...           1
# 7            0             0             1             119  ...           1
# 8            0             0             0             131  ...           1
# 9            0             0             1             119  ...           1
# 10           0             0             0             131  ...           1
# 11           0             0             1             119  ...           1
# 12           0             0             1             119  ...           1
# 13           0             0             1             119  ...           1
# 14           0             0             1             119  ...           1
# 15           0             0             1             119  ...           1
# 16           0             0             1             119  ...           1
# 17           0             0             1             119  ...           0
# 18           0             0             1             119  ...           0
# 19           0             0             0             131  ...           0
# 20           0             0             1             119  ...          -1
# 21           0             0             1             119  ...           0
# 22           0             0             0             117  ...           0
# 23           0             0             1             119  ...           1
# 24           0             0             1             119  ...           1
# 25           0             0             1             119  ...           1
# 26           0             0             1             119  ...           0
# 27           0             0             1             119  ...           0
#
#     aromatic_aa7  polarity_aa8  Molar Mass_aa8  charge_aa8  aromatic_aa8  \
# 0              0             1             132          -1             0
# 1              0             1             132          -1             0
# 2              0             1             132          -1             0
# 3              0             1             132          -1             0
# 4              0             1             132          -1             0
# 5              0             1             132          -1             0
# 6              0             1             132          -1             0
# 7              0             1             132          -1             0
# 8              0             1             132          -1             0
# 9              0             1             132          -1             0
# 10             0             1             132          -1             0
# 11             0             1             132          -1             0
# 12             0             1             132          -1             0
# 13             0             1             132          -1             0
# 14             0             1             132          -1             0
# 15             0             1             132          -1             0
# 16             0             1             132          -1             0
# 17             0             1             132          -1             0
# 18             0             1             132          -1             0
# 19             0             1             132          -1             0
# 20             0             1             132           0             0
# 21             0             1             105           0             0
# 22             0             1             147           1             0
# 23             0             1             132          -1             0
# 24             0             1             132          -1             0
# 25             0             1             132          -1             0
# 26             0             1             132          -1             0
# 27             0             1             146           0             0
#
#     polarity_aa9  Molar Mass_aa9  charge_aa9  aromatic_aa9
# 0              0             115           0             0
# 1              0             115           0             0
# 2              0             115           0             0
# 3              0             115           0             0
# 4              0             115           0             0
# 5              0             115           0             0
# 6              0             115           0             0
# 7              0             115           0             0
# 8              0             115           0             0
# 9              0             115           0             0
# 10             0             115           0             0
# 11             0             115           0             0
# 12             0             115           0             0
# 13             0             115           0             0
# 14             0             115           0             0
# 15             0             115           0             0
# 16             0             115           0             0
# 17             0             115           0             0
# 18             0             115           0             0
# 19             0             115           0             0
# 20             0             115           0             0
# 21             0             115           0             0
# 22             0             115           0             0
# 23             1             119           0             0
# 24             0             117           0             0
# 25             0             117           0             0
# 26             1             105           0             0
# 27             1             155           1             1
#
# [28 rows x 36 columns]

# %%
y_test = Ortho_merged['resistance']

y_test
# Out:
# 0     resistant
# 1     sensitive
# 2     resistant
# 3     resistant
# 4     resistant
# 5     resistant
# 6     sensitive
# 7     resistant
# 8     resistant
# 9     resistant
# 10    resistant
# 11    sensitive
# 12    sensitive
# 13    resistant
# 14    sensitive
# 15    resistant
# 16    sensitive
# 17    resistant
# 18    sensitive
# 19    sensitive
# 20    resistant
# 21    resistant
# 22    resistant
# 23    sensitive
# 24    resistant
# 25    resistant
# 26    resistant
# 27    resistant
# Name: resistance, dtype: object

# %% [markdown]
# ## Machine Learning

# %%
# Use Gridsearch & Random Forest

print(drug)

if drug == 'caspofungin' :
    grid = {'n_estimators': [100],
            'max_features': [9, 14, 15, 17, 23, 25],
            'max_depth': [10,12,15,20,23,25],
            'min_samples_split': [2],
            'min_samples_leaf' : [1],
            'random_state': [18]}

elif drug == 'anidulafungin' :
    grid = {'n_estimators': [100],
            'max_features': [9, 13, 17, 23, 25],
            'max_depth': [10, 12, 15, 17,20],
            'min_samples_split': [2],
            'min_samples_leaf' : [1],
            'random_state': [18]}

elif drug == 'micafungin' :
    grid = {'n_estimators': [100],
            'max_features': [15,17,19,20,21,23],
            'max_depth': [7,8,10,12,13,14],
            'min_samples_split': [2],
            'min_samples_leaf' : [1],
            'random_state': [18]}

else:
    print("Wrong drug")


CV_rf = GridSearchCV(estimator=RandomForestClassifier(), param_grid=grid, n_jobs=-1, cv=ShuffleSplit(n_splits=5, test_size=0.2, random_state=18), scoring='balanced_accuracy')
CV_rf.fit(X_train, y_train)
#rf = CV_rf.best_estimator_
print(CV_rf.best_params_)

#rf.fit(X_train, y_train)

y_pred = CV_rf.predict(X_test)
# Out:
# caspofungin
# {'max_depth': 23, 'max_features': 9, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 18}

# %%
# See splits

CVdf = pd.DataFrame(data=CV_rf.cv_results_)

CVdf
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.185340      0.014372         0.013835        0.000730
# 1        0.182414      0.003626         0.013193        0.000218
# 2        0.174474      0.004042         0.013097        0.000276
# 3        0.171639      0.002566         0.013467        0.000605
# 4        0.184162      0.007593         0.013714        0.000648
# 5        0.180706      0.005276         0.013196        0.000084
# 6        0.169283      0.003166         0.013271        0.000117
# 7        0.169431      0.001355         0.013204        0.000080
# 8        0.170444      0.001631         0.012864        0.000141
# 9        0.169940      0.001378         0.012759        0.000090
# 10       0.175485      0.002345         0.012890        0.000091
# 11       0.175554      0.001855         0.012885        0.000119
# 12       0.167825      0.000922         0.012825        0.000362
# 13       0.173936      0.001397         0.014265        0.002570
# 14       0.197592      0.024048         0.016234        0.002772
# 15       0.221395      0.056200         0.013900        0.001646
# 16       0.199763      0.013592         0.013826        0.001295
# 17       0.181489      0.002099         0.012675        0.000102
# 18       0.167156      0.000639         0.012698        0.000250
# 19       0.176733      0.003982         0.012863        0.000157
# 20       0.172180      0.001289         0.012774        0.000099
# 21       0.178514      0.005206         0.012964        0.000194
# 22       0.178106      0.001434         0.012828        0.000259
# 23       0.179300      0.001063         0.012786        0.000144
# 24       0.169122      0.001381         0.012966        0.000263
# 25       0.171276      0.001272         0.012859        0.000237
# 26       0.173511      0.002079         0.012848        0.000120
# 27       0.184491      0.017646         0.013715        0.001725
# 28       0.192889      0.012491         0.015600        0.003194
# 29       0.233999      0.054382         0.013233        0.000849
# 30       0.183756      0.019946         0.012952        0.000267
# 31       0.177936      0.005248         0.012959        0.000288
# 32       0.173393      0.001680         0.012841        0.000087
# 33       0.176649      0.001170         0.012899        0.000234
# 34       0.181082      0.004284         0.013009        0.000273
# 35       0.156789      0.016749         0.008739        0.001783
#
#    param_max_depth param_max_features param_min_samples_leaf  \
# 0               10                  9                      1
# 1               10                 14                      1
# 2               10                 15                      1
# 3               10                 17                      1
# 4               10                 23                      1
# 5               10                 25                      1
# 6               12                  9                      1
# 7               12                 14                      1
# 8               12                 15                      1
# 9               12                 17                      1
# 10              12                 23                      1
# 11              12                 25                      1
# 12              15                  9                      1
# 13              15                 14                      1
# 14              15                 15                      1
# 15              15                 17                      1
# 16              15                 23                      1
# 17              15                 25                      1
# 18              20                  9                      1
# 19              20                 14                      1
# 20              20                 15                      1
# 21              20                 17                      1
# 22              20                 23                      1
# 23              20                 25                      1
# 24              23                  9                      1
# 25              23                 14                      1
# 26              23                 15                      1
# 27              23                 17                      1
# 28              23                 23                      1
# 29              23                 25                      1
# 30              25                  9                      1
# 31              25                 14                      1
# 32              25                 15                      1
# 33              25                 17                      1
# 34              25                 23                      1
# 35              25                 25                      1
#
#    param_min_samples_split param_n_estimators param_random_state  \
# 0                        2                100                 18
# 1                        2                100                 18
# 2                        2                100                 18
# 3                        2                100                 18
# 4                        2                100                 18
# 5                        2                100                 18
# 6                        2                100                 18
# 7                        2                100                 18
# 8                        2                100                 18
# 9                        2                100                 18
# 10                       2                100                 18
# 11                       2                100                 18
# 12                       2                100                 18
# 13                       2                100                 18
# 14                       2                100                 18
# 15                       2                100                 18
# 16                       2                100                 18
# 17                       2                100                 18
# 18                       2                100                 18
# 19                       2                100                 18
# 20                       2                100                 18
# 21                       2                100                 18
# 22                       2                100                 18
# 23                       2                100                 18
# 24                       2                100                 18
# 25                       2                100                 18
# 26                       2                100                 18
# 27                       2                100                 18
# 28                       2                100                 18
# 29                       2                100                 18
# 30                       2                100                 18
# 31                       2                100                 18
# 32                       2                100                 18
# 33                       2                100                 18
# 34                       2                100                 18
# 35                       2                100                 18
#
#                                                params  split0_test_score  \
# 0   {'max_depth': 10, 'max_features': 9, 'min_samp...           0.862069
# 1   {'max_depth': 10, 'max_features': 14, 'min_sam...           0.862069
# 2   {'max_depth': 10, 'max_features': 15, 'min_sam...           0.879310
# 3   {'max_depth': 10, 'max_features': 17, 'min_sam...           0.879310
# 4   {'max_depth': 10, 'max_features': 23, 'min_sam...           0.896552
# 5   {'max_depth': 10, 'max_features': 25, 'min_sam...           0.879310
# 6   {'max_depth': 12, 'max_features': 9, 'min_samp...           0.896552
# 7   {'max_depth': 12, 'max_features': 14, 'min_sam...           0.879310
# 8   {'max_depth': 12, 'max_features': 15, 'min_sam...           0.879310
# 9   {'max_depth': 12, 'max_features': 17, 'min_sam...           0.879310
# 10  {'max_depth': 12, 'max_features': 23, 'min_sam...           0.896552
# 11  {'max_depth': 12, 'max_features': 25, 'min_sam...           0.879310
# 12  {'max_depth': 15, 'max_features': 9, 'min_samp...           0.931034
# 13  {'max_depth': 15, 'max_features': 14, 'min_sam...           0.896552
# 14  {'max_depth': 15, 'max_features': 15, 'min_sam...           0.896552
# 15  {'max_depth': 15, 'max_features': 17, 'min_sam...           0.896552
# 16  {'max_depth': 15, 'max_features': 23, 'min_sam...           0.871552
# 17  {'max_depth': 15, 'max_features': 25, 'min_sam...           0.871552
# 18  {'max_depth': 20, 'max_features': 9, 'min_samp...           0.931034
# 19  {'max_depth': 20, 'max_features': 14, 'min_sam...           0.906034
# 20  {'max_depth': 20, 'max_features': 15, 'min_sam...           0.906034
# 21  {'max_depth': 20, 'max_features': 17, 'min_sam...           0.906034
# 22  {'max_depth': 20, 'max_features': 23, 'min_sam...           0.906034
# 23  {'max_depth': 20, 'max_features': 25, 'min_sam...           0.906034
# 24  {'max_depth': 23, 'max_features': 9, 'min_samp...           0.931034
# 25  {'max_depth': 23, 'max_features': 14, 'min_sam...           0.906034
# 26  {'max_depth': 23, 'max_features': 15, 'min_sam...           0.906034
# 27  {'max_depth': 23, 'max_features': 17, 'min_sam...           0.906034
# 28  {'max_depth': 23, 'max_features': 23, 'min_sam...           0.906034
# 29  {'max_depth': 23, 'max_features': 25, 'min_sam...           0.906034
# 30  {'max_depth': 25, 'max_features': 9, 'min_samp...           0.931034
# 31  {'max_depth': 25, 'max_features': 14, 'min_sam...           0.906034
# 32  {'max_depth': 25, 'max_features': 15, 'min_sam...           0.906034
# 33  {'max_depth': 25, 'max_features': 17, 'min_sam...           0.906034
# 34  {'max_depth': 25, 'max_features': 23, 'min_sam...           0.906034
# 35  {'max_depth': 25, 'max_features': 25, 'min_sam...           0.906034
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.828070           0.888793           0.799283
# 1            0.844737           0.854310           0.799283
# 2            0.844737           0.854310           0.799283
# 3            0.844737           0.888793           0.799283
# 4            0.844737           0.888793           0.799283
# 5            0.844737           0.854310           0.799283
# 6            0.844737           0.888793           0.815412
# 7            0.861404           0.863793           0.815412
# 8            0.844737           0.888793           0.799283
# 9            0.861404           0.888793           0.815412
# 10           0.861404           0.863793           0.815412
# 11           0.861404           0.838793           0.815412
# 12           0.878070           0.838793           0.831541
# 13           0.878070           0.863793           0.831541
# 14           0.878070           0.838793           0.831541
# 15           0.878070           0.863793           0.815412
# 16           0.851754           0.813793           0.831541
# 17           0.878070           0.838793           0.863799
# 18           0.878070           0.813793           0.847670
# 19           0.851754           0.831034           0.847670
# 20           0.851754           0.856034           0.847670
# 21           0.851754           0.831034           0.847670
# 22           0.851754           0.831034           0.847670
# 23           0.851754           0.806034           0.863799
# 24           0.878070           0.831034           0.847670
# 25           0.878070           0.831034           0.847670
# 26           0.851754           0.831034           0.847670
# 27           0.851754           0.831034           0.847670
# 28           0.851754           0.831034           0.847670
# 29           0.851754           0.806034           0.847670
# 30           0.878070           0.806034           0.847670
# 31           0.851754           0.806034           0.847670
# 32           0.851754           0.831034           0.847670
# 33           0.878070           0.831034           0.847670
# 34           0.851754           0.831034           0.847670
# 35           0.851754           0.806034           0.847670
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.913793         0.858402        0.041037               30
# 1            0.896552         0.851390        0.031374               36
# 2            0.896552         0.854838        0.033249               34
# 3            0.913793         0.865183        0.039701               16
# 4            0.888793         0.863632        0.037007               17
# 5            0.888793         0.853287        0.031396               35
# 6            0.913793         0.871857        0.036268                7
# 7            0.896552         0.863294        0.027052               25
# 8            0.871552         0.856735        0.032254               32
# 9            0.888793         0.866742        0.027545               14
# 10           0.888793         0.865191        0.028407               15
# 11           0.888793         0.856742        0.026790               31
# 12           0.913793         0.878646        0.039465                2
# 13           0.906034         0.875198        0.026272                4
# 14           0.906034         0.870198        0.030071                9
# 15           0.906034         0.871972        0.031836                6
# 16           0.906034         0.854935        0.032054               33
# 17           0.906034         0.871650        0.021747                8
# 18           0.906034         0.875320        0.041485                3
# 19           0.906034         0.868506        0.031419               13
# 20           0.881034         0.868506        0.022071               12
# 21           0.881034         0.863506        0.026680               18
# 22           0.881034         0.863506        0.026680               18
# 23           0.881034         0.861731        0.033291               26
# 24           0.906034         0.878769        0.036664                1
# 25           0.881034         0.868769        0.026438               10
# 26           0.881034         0.863506        0.026680               18
# 27           0.881034         0.863506        0.026680               18
# 28           0.881034         0.863506        0.026680               18
# 29           0.881034         0.858506        0.033713               27
# 30           0.906034         0.873769        0.043836                5
# 31           0.881034         0.858506        0.033713               27
# 32           0.881034         0.863506        0.026680               18
# 33           0.881034         0.868769        0.026438               10
# 34           0.881034         0.863506        0.026680               18
# 35           0.881034         0.858506        0.033713               27

# %%
y_pred_train = CV_rf.predict(X_train)
    
bal_acc_train = balanced_accuracy_score(y_train, y_pred_train)
print(bal_acc_train)

bal_acc_test = balanced_accuracy_score(y_test, y_pred)
print(bal_acc_test)
# Out:
# 0.9708727580850163
# 0.8918128654970761

# %%
export_df = pd.DataFrame(data=[y_test,y_pred])
export_df = export_df.T
export_df.rename(columns={'resistance': 'y_test'}, inplace=True)
export_df.rename(columns={'Unnamed 0': 'y_pred'}, inplace=True)

#export_df.to_csv(f'{outpath}/{drug}_ML_orthologs_results.csv', index=False)

export_df
# Out:
#        y_test     y_pred
# 0   resistant  sensitive
# 1   sensitive  sensitive
# 2   resistant  resistant
# 3   resistant  resistant
# 4   resistant  resistant
# 5   resistant  resistant
# 6   sensitive  sensitive
# 7   resistant  resistant
# 8   resistant  resistant
# 9   resistant  resistant
# 10  resistant  resistant
# 11  sensitive  sensitive
# 12  sensitive  sensitive
# 13  resistant  sensitive
# 14  sensitive  sensitive
# 15  resistant  resistant
# 16  sensitive  sensitive
# 17  resistant  resistant
# 18  sensitive  sensitive
# 19  sensitive  sensitive
# 20  resistant  resistant
# 21  resistant  resistant
# 22  resistant  resistant
# 23  sensitive  resistant
# 24  resistant  resistant
# 25  resistant  resistant
# 26  resistant  resistant
# 27  resistant  resistant

# %%
proba = CV_rf.predict_proba(X_test)[::,1]

proba_df = pd.DataFrame(data=proba)
#proba_df.to_csv(f'{outpath}/{drug}_ML_ROCproba.csv', index=False)

# End of code.

# %% [markdown]
# ## SHAP values

# %%
# shap
rf = CV_rf.best_estimator_
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X_test)

# Max display controls number of features shown
shap.summary_plot(shap_values[0], X_test, show=False, plot_size=(16,8), max_display=5)

plt.gca().set_facecolor('white')
plt.grid(False)

# Modifying main plot parameters
plt.gca().tick_params(labelsize=20)
plt.gca().set_xlabel("SHAP value (impact on model output)", fontsize=20)
plt.gca().set_title(f'{drug} feature importance', fontsize=24)

# Get colorbar
cb_ax = plt.gcf().axes[1]

# Modifying color bar parameters
cb_ax.tick_params(labelsize=20)
cb_ax.set_ylabel("Feature value", fontsize=20)

# Adjust dot size
summary_plot = plt.gcf()
for scatter in summary_plot.axes[0].collections:
    scatter.set_sizes([300])  # Adjust the size as needed

#plt.savefig(f'{outpath}/{drug}_shapValues.svg')
plt.show()


# Most important Features (MIF)
vals= np.abs(shap_values).mean(0)
feature_importance = pd.DataFrame(list(zip(X_test.columns, sum(vals))), columns=['col_name','feature_importance_vals'])
feature_importance.sort_values(by=['feature_importance_vals'], ascending=False,inplace=True)

mif = feature_importance.head()['col_name'].to_list()
print(mif)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# ['Molar Mass_aa3', 'polarity', 'Molar Mass', 'charge_aa8', 'Molar Mass_aa9']

# %%
#%% other SHAP plot
import shap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
## Compute SHAP values
# Create SHAP explainer for the trained model (brf) and calculate SHAP values for the test data (X_test_s)
explainer = shap.Explainer(rf)
shap_values = explainer(X_test)
# Plot a beeswarm plot for the first class (0) using the shap package
#shap.plots.beeswarm(shap_values[:,:,0])

## Extract SHAP values and reshape df
# Create DataFrames for SHAP values and original data
shap = pd.DataFrame(shap_values.values[:,:,0])
data = pd.DataFrame(shap_values.data)
columns = X_test.columns
shap.columns = columns
data.columns = columns

# Function to normalize a column to the range [0, 1]
def min_max_scaling(column):
    min_val = column.min()
    max_val = column.max()
    if min_val == max_val:
        return column
    else:
        return (column - min_val) / (max_val - min_val)

    # Apply min-max scaling to each column in the original data DataFrame
data = data.apply(min_max_scaling)
# Reshape SHAP values DataFrame and original data DataFrame for plotting
shap_long = shap.melt(var_name='Features', value_name='Shap values')
data_long = data.melt(var_name='Features', value_name='Data')
# Concatenate SHAP values and original data for plotting
df = pd.concat([shap_long, data_long['Data']], axis=1)


## Custom plot
# Define a custom color map for the beeswarm plot
colors = [(0.0, 'dodgerblue'), (0.5, 'blueviolet'), (1.0, 'red')]
cmap_name = "shap_beeswarm"
custom_cmap = LinearSegmentedColormap.from_list(cmap_name, colors)
# Plot a color gradient to visualize the custom color map
gradient = np.linspace(0, 1, 256).reshape(1, -1)
gradient = np.vstack((gradient, gradient))
fig, ax = plt.subplots(figsize=(7.6, 0.3))
ax.set_xticks([])
ax.set_yticks([])
ax.imshow(gradient, aspect="auto", cmap=custom_cmap)
plt.show()

# Select specific columns for the final strip plot. Using the most important features.
columns = mif

# Create a strip plot for selected columns using SHAP values and original data
fig, ax = plt.subplots(figsize=(7.6, 6))
sns.set(font_scale=2)

sns.stripplot(data=df[df['Features'].isin(columns)], x='Features', y='Shap values', hue='Data',
              legend=False, jitter=True, palette=custom_cmap, size=10, order=columns)

ax.set_ylim(-0.11, 0.12)
plt.xlabel('')
plt.ylabel('SHAP value')

plt.xticks(rotation=45, ha='right', rotation_mode='anchor')
ax.grid(axis='x', linewidth=2, color='gray')
ax.axhline(y=0, color='gray', linestyle='--', linewidth=2)
ax.yaxis.grid(False)

# Get unique categories from the X-axis variable
categories = df["Features"].unique()

# Set the colors for alternating background regions
background_colors = ['#F2F2F2', 'white']

# Iterate through categories and add alternating background patches
for i, cat in enumerate(categories):
    color = background_colors[i % 2]
    x_values = df[df['Features'] == cat]['Features'].values
    x_range = (i - 0.5, i + 0.5)
    y_range = ax.get_ylim()
    ax.add_patch(plt.Rectangle((x_range[0], y_range[0]), x_range[1] - x_range[0], y_range[1] - y_range[0], color=color, zorder=-1))

plt.gca().set_title(f'{drug} feature importance', fontsize=24)    
plt.show()
