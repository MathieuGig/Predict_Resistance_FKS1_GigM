# %% [markdown]
# # Combine S2 Taxonomy Dataframes

# %%
import pandas as pd
import numpy as np

# %%
def combine(df1, df2):
    
    dataframe1 = pd.read_csv(df1, index_col=0)
    dataframe2 = pd.read_csv(df2, index_col=0)
    
    # Add new column
    dataframe1['Paralog'] = 'Fks1'
    dataframe2['Paralog'] = 'Fks2'
    
    dataframe3 = pd.concat([dataframe1, dataframe2])
    
    dataframe3 = dataframe3[['Species', 'Kingdom', 'Phylum', 'Paralog', 'Hotspot1', 'Hotspot2',
     'GapsHotspot1',
     'GapsHotspot2',
     'HS1_in_oPools',
     'HS2_in_oPools',
     'Is_Human_Pathogen']]
    
    return dataframe3

combinedDF = combine('S2_FKS1_Taxonomy.csv', 'S2_FKS2_Taxonomy.csv')

combinedDF
# Out:
#                                      Species        Kingdom        Phylum  \
# Identifier
# M!149570508_CHLRE  Chlamydomonas reinhardtii  Viridiplantae   Chlorophyta
# M!114407260_ARATH       Arabidopsis thaliana  Viridiplantae  Streptophyta
# M!114427513_ARATH       Arabidopsis thaliana  Viridiplantae  Streptophyta
# M!150549500_PHYBL   Phycomyces blakesleeanus          Fungi  Mucoromycota
# M!85749882_RHIOR             Rhizopus oryzae          Fungi  Mucoromycota
# ...                                      ...            ...           ...
# M!42720474_ASPNG           Aspergillus niger          Fungi    Ascomycota
# M!72544156_ASPTE         Aspergillus terreus          Fungi    Ascomycota
# M!42229600_ASPCV        Aspergillus clavatus          Fungi    Ascomycota
# M!146275252_ASPFM      Aspergillus fumigatus          Fungi    Ascomycota
# M!74984599_36630        Aspergillus fischeri          Fungi    Ascomycota
#
#                   Paralog   Hotspot1  Hotspot2  GapsHotspot1  GapsHotspot2  \
# Identifier
# M!149570508_CHLRE    Fks1  AICSDLRED  QLGT----         False          True
# M!114407260_ARATH    Fks1  LQVKPMIKP  GVILNQQF         False         False
# M!114427513_ARATH    Fks1  LQIRPLIAP  NQQFIIQL         False         False
# M!150549500_PHYBL    Fks1  FLALSFRDA  EWIQRCVL         False         False
# M!85749882_RHIOR     Fks1  FLALSFRDA  DWLQRCML         False         False
# ...                   ...        ...       ...           ...           ...
# M!42720474_ASPNG     Fks2   LTLSLKDP  AWVNRCVV         False         False
# M!72544156_ASPTE     Fks2   LTLSFKDP  DWVNRCVI         False         False
# M!42229600_ASPCV     Fks2   LTLSIKDP  DWVNRCII         False         False
# M!146275252_ASPFM    Fks2   LTLSFKDP  DWVNRCII         False         False
# M!74984599_36630     Fks2   LTLSFKDP  DWVNRCII         False         False
#
#                    HS1_in_oPools  HS2_in_oPools  Is_Human_Pathogen
# Identifier
# M!149570508_CHLRE           True          False              False
# M!114407260_ARATH           True           True              False
# M!114427513_ARATH           True           True              False
# M!150549500_PHYBL           True           True              False
# M!85749882_RHIOR            True           True              False
# ...                          ...            ...                ...
# M!42720474_ASPNG            True           True              False
# M!72544156_ASPTE            True           True              False
# M!42229600_ASPCV            True           True              False
# M!146275252_ASPFM           True           True               True
# M!74984599_36630            True           True              False
#
# [409 rows x 11 columns]

# %%
combinedDF.to_csv('S2_taxonomy.csv', index=False)
